# %%
# Necessary Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the data
data = pd.read_csv('StudentsPerformance.csv')

# %%
# Prints the first 5 rows
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# Checks the rows and column
data.shape
# Out:
# (1000, 8)

# %%
# Gives the information about the dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
# Checks the null values in the dataframe
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
# Statistical Measure
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
# Checks the correlation 
data.corr()
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
plt.figure(figsize=(12,6))
plt.title('Correlation Matrix')
sns.heatmap(data.corr(), annot=True, fmt='.1f', cbar=True, cmap='Wistia');

# %%
# Prints the unique values
print(data['gender'].unique())
print(data['race/ethnicity'].unique())
print(data['parental level of education'].unique())
print(data['lunch'].unique())
print(data['test preparation course'].unique())
# Out:
# ['female' 'male']
# ['group B' 'group C' 'group A' 'group D' 'group E']
# ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
# ['standard' 'free/reduced']
# ['none' 'completed']

# %%
data['math score'].value_counts()
# Out:
# 65    36
# 62    35
# 69    32
# 59    32
# 61    27
#       ..
# 24     1
# 28     1
# 33     1
# 18     1
# 8      1
# Name: math score, Length: 81, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title('Math Score Distribution')
sns.histplot(data=data, 
             x='math score', 
             color='red', 
             kde=True)
plt.show();

# %% [markdown]
# ## Insight
# Data is skewed to the left, that means mean is less than the median

# %%
plt.figure(figsize=(12,6))
plt.title('Math Score Distribution')
sns.boxplot(data=data, x='math score', palette='Pastel1')
plt.show();

# %% [markdown]
# ## Insight
# As you can see in math score have some outlires.

# %%
data['reading score'].value_counts()
# Out:
# 72    34
# 74    33
# 64    32
# 67    30
# 73    30
#       ..
# 28     1
# 26     1
# 17     1
# 32     1
# 40     1
# Name: reading score, Length: 72, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title('Reading Score Distribution')
sns.histplot(data=data, 
             x='reading score', 
             color='blue', 
             kde=True)
plt.show();

# %% [markdown]
# ## Insight
# Data is skewed to the left in reading score, that means mean is less than the median.

# %%
plt.figure(figsize=(12,6))
plt.title('Reading Score Distribution')
sns.boxplot(data=data, x='reading score', palette='viridis')
plt.show();

# %% [markdown]
# ## Insight
# As you can see in Reading score have some outlires.

# %%
data['writing score'].value_counts()
# Out:
# 74    35
# 70    33
# 68    31
# 73    28
# 80    27
#       ..
# 28     1
# 35     1
# 19     1
# 22     1
# 23     1
# Name: writing score, Length: 77, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title('Writing Score Distribution')
sns.histplot(data=data, 
             x='writing score', 
             color='orange', 
             kde=True)
plt.show();

# %% [markdown]
# ## Insight
# Data is skewed to the left in writing score, that means mean is less than the median.

# %%
plt.figure(figsize=(12,6))
plt.title('Writing Score Distribution')
sns.boxplot(data=data, x='writing score', palette='icefire')
plt.show();

# %% [markdown]
# ## Insight
# As you can see in writing score have some outlires.

# %%
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title('Gender')
sns.countplot(data=data, x='gender', palette='Accent')
plt.show();

# %% [markdown]
# ## Insight
# Female's are more than Male's.

# %%
plt.figure(figsize=(12,6))
plt.title('Gender VS Math Score')
sns.barplot(data=data, 
            x='gender',  
            y='math score', 
            palette='Accent_r')
plt.show();

# %% [markdown]
# ## Insight
# Male have more score in math's than female.

# %%
plt.figure(figsize=(12,6))
plt.title('Gender VS Reading Score')
sns.barplot(data=data, 
            x='gender',  
            y='reading score', 
            palette='PRGn')
plt.show();

# %% [markdown]
# ## Insight
# Female have more score in reading than male.

# %%
plt.figure(figsize=(12,6))
plt.title('Gender VS Writing Score')
sns.barplot(data=data, 
            x='gender',  
            y='writing score', 
            palette='Paired_r')
plt.show();

# %% [markdown]
# ## Insight
# Female have score more in writing than male.

# %%
data['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title('Ethnicity')
sns.countplot(data=data, x='race/ethnicity', palette='RdYlBu')
plt.show();

# %% [markdown]
# ## Insight
# Based on ethnicity Group C have more people.

# %%
plt.figure(figsize=(12,6))
plt.title('Ethnicity Based On Gender')
sns.countplot(data=data, 
              x='race/ethnicity', 
              hue='gender', 
              palette='gist_earth')
plt.show();

# %% [markdown]
# ## Insight
# Group A, D and E have more male than female.
# Group B and C have more female than male.

# %%
plt.figure(figsize=(12,6))
plt.title('Ethnicity VS Math Score')
sns.barplot(data=data, 
            x='race/ethnicity', 
            y='math score', 
            palette='Dark2_r')
plt.show();

# %% [markdown]
# ## Insight
# Group E scores more in math's as compared to other groups.

# %%
plt.figure(figsize=(12,6))
plt.title('Ethnicity VS Reading Score')
sns.barplot(data=data, 
            x='race/ethnicity', 
            y='reading score', 
            palette='Purples')
plt.show();

# %% [markdown]
# ## Insight
# Group E scores more in reading as compared to other groups.

# %%
plt.figure(figsize=(12,6))
plt.title('Ethnicity VS Writing Score')
sns.barplot(data=data, 
            x='race/ethnicity', 
            y='writing score', 
            palette='pink')
plt.show();

# %% [markdown]
# ## Insight
# Group E and D scores more in writing as compared to other groups.

# %%
data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title('Parental Education')
sns.countplot(data=data, x='parental level of education', palette='vlag')
plt.show();

# %% [markdown]
# ## Insight
# Parental Education of student have more college degree and associate degree.

# %%
plt.figure(figsize=(12,6))
plt.title('Parental Education Based On Gender')
sns.countplot(data=data, 
              x='parental level of education', 
              hue='gender', 
              palette='seismic')
plt.show();

# %% [markdown]
# ## Insight
# Female student parent's are more educated than male student.

# %%
data['lunch'].value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title('Lunch')
sns.countplot(data=data, x='lunch', palette='coolwarm_r')
plt.show();

# %% [markdown]
# ## Insight
# Student's prefer standard lunch as compared to free lunch.

# %%
plt.figure(figsize=(12,6))
plt.title('Lunch Based On Gender')
sns.countplot(data=data, 
              x='lunch', 
              palette='cubehelix_r', 
              hue='gender', 
              dodge=True)
plt.show();

# %% [markdown]
# ## Insight
# More female student prefer both standard and free lunch as compared to male student.

# %%
data['test preparation course'].value_counts()
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title('Test Prepration Course')
sns.countplot(data=data, x='test preparation course', palette='PuOr')
plt.show();

# %% [markdown]
# ## Insight
# Majortiy of students are not completed there test prepration course.

# %%
plt.figure(figsize=(12,6))
plt.title('Test Prepration Course Based On Gender')
sns.countplot(data=data, 
              x='test preparation course', 
              hue='gender', 
              palette='bone')
plt.show();

# %% [markdown]
# ## Insight
# Majority of female students are more who have completed or not completed there test prepration course.

# %%
plt.figure(figsize=(12,6))
plt.title('Test Prepration Course VS Math Score')
sns.barplot(data=data, 
            x='test preparation course', 
            y='math score', 
            hue='gender', 
            palette='magma')
plt.show();

# %% [markdown]
# ## Insight
# Majority of male student are score more in maths as compared to female student, if there test prepration course is complete or not.

# %%
plt.figure(figsize=(12,6))
plt.title('Test Prepration Course VS Reading Score')
sns.barplot(data=data, 
            x='test preparation course', 
            y='reading score', 
            hue='gender', 
            palette='inferno')
plt.show();

# %% [markdown]
# ## Insight
# Majority of female student are score more in reading as compared to female student, if there test prepration course is complete or not.

# %%
plt.figure(figsize=(12,6))
plt.title('Test Prepration Course VS Writing Score')
sns.barplot(data=data, 
            x='test preparation course', 
            y='writing score', 
            hue='gender', 
            palette='copper')
plt.show();

# %% [markdown]
# ## Insight
# Majority of female student are score more in Writing as compared to female student,  if there test prepration course is complete or not.
